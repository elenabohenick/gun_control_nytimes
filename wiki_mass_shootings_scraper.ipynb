# %%
import requests
from bs4 import BeautifulSoup
import string
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url = 'https://en.wikipedia.org/wiki/Mass_shootings_in_the_United_States'

response=requests.get(url)
page=response.text

soup=BeautifulSoup(page,"html5lib")

# %%
# grab tge table with data
table = soup.find("table")
df = pd.read_html(str(table))
df = df[0]
df.columns = df.iloc[0]
df = df.iloc[1:]

# %%
# clean up column names
df.columns = [str(c).strip() for c in df.columns]
df.columns
# Out:
# Index(['nan', 'Incident', 'Year', 'Deaths', 'Injuries',
#        'Type of firearm(s) used', 'Ref(s)'],
#       dtype='object')

# %%
# since some of the data is shifted, identify what rows got shifted by one column
df['shifted'] = [any(c.isalpha() for c in col) for col in df['nan']]

# %%
# split into correct and shifted dfs
df_1 = df[df['shifted']==False]
df_2 = df[df['shifted']==True]

# %%
df_1 = df_1.iloc[:,1:6].copy()
df_2 = df_2.iloc[:,:5].copy()

# %%
df_2.columns = df_1.columns

# %%
df = pd.concat([df_1,df_2])

# %%
df['Year'] = [int(y) for y in df['Year']]
df['Injuries'] = [int(i.split(' ')[0]) for i in df['Injuries']]
df['Deaths'] = [int(d.split(' ')[0]) for d in df['Deaths']]

# %%
df.sort_values(by='Year',ascending=True,inplace=True)
df
# Out:
#                                  Incident  Year  Deaths  Injuries  \
# 15                       Camden shootings  1949      13         3
# 8      University of Texas tower shooting  1966      18        31
# 20                 Easter Sunday massacre  1975      11         0
# 16                 Wilkes-Barre shootings  1982      13         1
# 17                       Wah Mee massacre  1983      13         1
# 7          San Ysidro McDonald's massacre  1984      23        19
# 22                   Palm Sunday massacre  1984      10         0
# 11            Edmond post office shooting  1986      15         6
# 23                         GMAC shootings  1990      10         6
# 6                         Luby's shooting  1991      24        27
# 24                      Atlanta shootings  1999      10        13
# 12         Columbine High School massacre  1999      15        24
# 25                     Red Lake shootings  2005      10         5
# 3                  Virginia Tech shooting  2007      33        23
# 14                     Fort Hood shooting  2009      14        33
# 13                   Binghamton shootings  2009      14         4
# 21                 Geneva County massacre  2009      11         6
# 4   Sandy Hook Elementary School shooting  2012      28         2
# 19                        Aurora shooting  2012      12        70
# 18          Washington Navy Yard shooting  2013      13         8
# 10                  San Bernardino attack  2015      16        24
# 26      Umpqua Community College shooting  2015      10         8
# 2              Orlando nightclub shooting  2016      50        58
# 1                      Las Vegas shooting  2017      59       851
# 5      Sutherland Springs church shooting  2017      27        20
# 9   Stoneman Douglas High School shooting  2018      17        17
# 27          Santa Fe High School shooting  2018      10        14
#
#                               Type of firearm(s) used
# 15                              Semi-automatic pistol
# 8   Semi-automatic rifles, revolver, pistols and s...
# 20                Semi-automatic pistols and revolver
# 16                               Semi-automatic rifle
# 17                         Multiple types of firearms
# 7                          Multiple types of firearms
# 22                             Semi-automatic pistols
# 11                             Semi-automatic pistols
# 23                               Semi-automatic rifle
# 6                              Semi-automatic pistols
# 24                Semi-automatic pistols and revolver
# 12                Shotguns and semi automatic pistols
# 25                 Semi-automatic pistols and shotgun
# 3                              Semi-automatic pistols
# 14                 Semi-automatic pistol and revolver
# 13                             Semi-automatic pistols
# 21       Semi-automatic rifles, revolver, and shotgun
# 4                     Semi-automatic rifle and pistol
# 19              Semi-automatic rifle, pistol, shotgun
# 18                  Semi-automatic pistol and shotgun
# 10                              Semi-automatic rifles
# 26                Semi-automatic pistols and revolver
# 2                     Semi-automatic rifle and pistol
# 1          Modified semi-automatic rifles and pistols
# 5                                Semi-automatic rifle
# 9                                Semi-automatic rifle
# 27                               Shotgun and revolver

# %%
# assign a count for each shooting in the same year
df['shooting_count'] = df.groupby(['Year']).cumcount()+1

# %%
df
# Out:
#                                  Incident  Year  Deaths  Injuries  \
# 15                       Camden shootings  1949      13         3
# 8      University of Texas tower shooting  1966      18        31
# 20                 Easter Sunday massacre  1975      11         0
# 16                 Wilkes-Barre shootings  1982      13         1
# 17                       Wah Mee massacre  1983      13         1
# 7          San Ysidro McDonald's massacre  1984      23        19
# 22                   Palm Sunday massacre  1984      10         0
# 11            Edmond post office shooting  1986      15         6
# 23                         GMAC shootings  1990      10         6
# 6                         Luby's shooting  1991      24        27
# 24                      Atlanta shootings  1999      10        13
# 12         Columbine High School massacre  1999      15        24
# 25                     Red Lake shootings  2005      10         5
# 3                  Virginia Tech shooting  2007      33        23
# 14                     Fort Hood shooting  2009      14        33
# 13                   Binghamton shootings  2009      14         4
# 21                 Geneva County massacre  2009      11         6
# 4   Sandy Hook Elementary School shooting  2012      28         2
# 19                        Aurora shooting  2012      12        70
# 18          Washington Navy Yard shooting  2013      13         8
# 10                  San Bernardino attack  2015      16        24
# 26      Umpqua Community College shooting  2015      10         8
# 2              Orlando nightclub shooting  2016      50        58
# 1                      Las Vegas shooting  2017      59       851
# 5      Sutherland Springs church shooting  2017      27        20
# 9   Stoneman Douglas High School shooting  2018      17        17
# 27          Santa Fe High School shooting  2018      10        14
#
#                               Type of firearm(s) used  shooting_count
# 15                              Semi-automatic pistol               1
# 8   Semi-automatic rifles, revolver, pistols and s...               1
# 20                Semi-automatic pistols and revolver               1
# 16                               Semi-automatic rifle               1
# 17                         Multiple types of firearms               1
# 7                          Multiple types of firearms               1
# 22                             Semi-automatic pistols               2
# 11                             Semi-automatic pistols               1
# 23                               Semi-automatic rifle               1
# 6                              Semi-automatic pistols               1
# 24                Semi-automatic pistols and revolver               1
# 12                Shotguns and semi automatic pistols               2
# 25                 Semi-automatic pistols and shotgun               1
# 3                              Semi-automatic pistols               1
# 14                 Semi-automatic pistol and revolver               1
# 13                             Semi-automatic pistols               2
# 21       Semi-automatic rifles, revolver, and shotgun               3
# 4                     Semi-automatic rifle and pistol               1
# 19              Semi-automatic rifle, pistol, shotgun               2
# 18                  Semi-automatic pistol and shotgun               1
# 10                              Semi-automatic rifles               1
# 26                Semi-automatic pistols and revolver               2
# 2                     Semi-automatic rifle and pistol               1
# 1          Modified semi-automatic rifles and pistols               1
# 5                                Semi-automatic rifle               2
# 9                                Semi-automatic rifle               1
# 27                               Shotgun and revolver               2

# %%
df['shooting_count'].unique()
# Out:
# array([1, 2, 3])

# %%
years = np.arange(1985,2019)

# %%
df_to_join = []
for y in years:
    for i in df['shooting_count'].unique():
        df_to_join.append([y,i])

# %%
df_to_join = pd.DataFrame(df_to_join, columns=['Year','shooting_count'])

# %%
df_to_plot = df_to_join.merge(df, how='left', on=['Year','shooting_count'])

# %%
df_to_plot.to_csv('mass_shootings_1985_2018.csv')
